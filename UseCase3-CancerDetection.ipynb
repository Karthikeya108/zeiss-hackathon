# %%
from hpi_classifier import HPImageClassifier

# %%
from skimage.io import imread
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
hpi_classifier = HPImageClassifier()
train, validation = hpi_classifier.get_data()
train_gen, valid_gen = hpi_classifier.augment_data(train, validation)
model = hpi_classifier.create_model()
model = hpi_classifier.train_model(model, train_gen, valid_gen)
hpi_classifier.save_model(model)
model_save_path.test_model(model,batch=5000)

# %%
hpi_classifier = HPImageClassifier()
model = hpi_classifier.load_model("/home/karthik/hackathon/code/model/inceptionv3.h5")

# %% [markdown]
# # Non-cancerous sample

# %%
img = imread("./images/clean.png")
plt.imshow(img)

# %%
img = cv2.cvtColor(np.array(img), cv2.COLOR_RGBA2RGB)
img = np.resize(img, (96, 96, 3))
print(img.shape)
hpi_classifier.predict(model, img)
# Out:
# 0.0025534227

# %% [markdown]
# # Cancerous sample

# %%
img = imread("./images/malign.tif")
plt.imshow(img)

# %%
hpi_classifier.predict(model, img)
# Out:
# 0.89383113
